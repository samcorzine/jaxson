# %%
import numpy as np
import cv2
from PIL import Image

from jaxson import Canvas

# Set up canvas
density = 2000
canvas = Canvas(density, density)

# Drawing logic
sum = canvas.zeros()
for x in range(10):
  sum = sum + canvas.circle(center_x=x*0.05, color=[0.8, 0.2, 0.2])

# Rendering
img = np.array(255 * sum)
img = Image.fromarray(img.astype("uint8"))
img
# Out:
# <PIL.Image.Image image mode=RGB size=2000x2000 at 0x14EA22340>

# %%
# Out:
# dtype('uint8')
